# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"28826615802","type":"PushEvent","actor":{"id":12237117,"login":"toddsharpe","display_login":"toddsharpe","gravatar_id":"","url":"https://api.github.com/users/toddsharpe","avatar_url":"https://avatars.githubusercontent.com/u/12237117?"},"repo":{"id":535972873,"name":"toddsharpe/Embedded","url":"https://api.github.com/repos/toddsharpe/Embedded"},"payload":{"repository_id":535972873,"push_id":13511615786,"size":2,"distinct_size":1,"ref":"refs/heads/master","head":"03f2c8014f6850d7f375c0b0b4d7680c42e612f3","before":"7fbf8375dc6ed6ec9cb8ce53a4f6bd5411a82fd7","commits":[{"sha":"7535b8d74b8d50a53656f313ffad09ef48a5952a","author":{"email":"toddsharpe@outlook.com","name":"Todd Sharpe"},"message":"External printf, Emulator ALU bug fix (OR), emulator UI","distinct":false,"url":"https://api.github.com/repos/toddsharpe/Embedded/commits/7535b8d74b8d50a53656f313ffad09ef48a5952a"},{"sha":"03f2c8014f6850d7f375c0b0b4d7680c42e612f3","author":{"email":"toddsharpe@outlook.com","name":"Todd Sharpe"},"message":"Merge pull request #23 from toddsharpe/dev/2023-04-26_remu\\n\\nExternal printf, Emulator ALU bug fix (OR), emulator UI","distinct":true,"url":"https://api.github.com/repos/toddsharpe/Embedded/commits/03f2c8014f6850d7f375c0b0b4d7680c42e612f3"}]},"public":true,"created_at":"2023-05-03T16:31:59Z"},{"id":"28826614614","type":"PullRequestReviewEvent","actor":{"id":60341450,"login":"murmurian","display_login":"murmurian","gravatar_id":"","url":"https://api.github.com/users/murmurian","avatar_url":"https://avatars.githubusercontent.com/u/60341450?"},"repo":{"id":589477904,"name":"tmc-coach/tmc-coach","url":"https://api.github.com/repos/tmc-coach/tmc-coach"},"payload":{"action":"created","review":{"id":1411299762,"node_id":"PRR_kwDOIyK4EM5UHrmy","user":{"login":"murmurian","id":60341450,"node_id":"MDQ6VXNlcjYwMzQxNDUw","avatar_url":"https://avatars.githubusercontent.com/u/60341450?v=4","gravatar_id":"","url":"https://api.github.com/users/murmurian","html_url":"https://github.com/murmurian","followers_url":"https://api.github.com/users/murmurian/followers","following_url":"https://api.github.com/users/murmurian/following{/other_user}","gists_url":"https://api.github.com/users/murmurian/gists{/gist_id}","starred_url":"https://api.github.com/users/murmurian/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/murmurian/subscriptions","organizations_url":"https://api.github.com/users/murmurian/orgs","repos_url":"https://api.github.com/users/murmurian/repos","events_url":"https://api.github.com/users/murmurian/events{/privacy}","received_events_url":"https://api.github.com/users/murmurian/received_events","type":"User","site_admin":false},"body":"Nooice","commit_id":"7aefb355e328600e96b580e76d54c750b793d431","submitted_at":"2023-05-03T16:31:55Z","state":"approved","html_url":"https://github.com/tmc-coach/tmc-coach/pull/247#pullrequestreview-1411299762","pull_request_url":"https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247","author_association":"CONTRIBUTOR","_links":{"html":{"href":"https://github.com/tmc-coach/tmc-coach/pull/247#pullrequestreview-1411299762"},"pull_request":{"href":"https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247"}}},"pull_request":{"url":"https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247","id":1336832769,"node_id":"PR_kwDOIyK4EM5PrnMB","html_url":"https://github.com/tmc-coach/tmc-coach/pull/247","diff_url":"https://github.com/tmc-coach/tmc-coach/pull/247.diff","patch_url":"https://github.com/tmc-coach/tmc-coach/pull/247.patch","issue_url":"https://api.github.com/repos/tmc-coach/tmc-coach/issues/247","number":247,"state":"open","locked":false,"title":"Fix refactoring and cleaning","user":{"login":"tuukkalai","id":8557415,"node_id":"MDQ6VXNlcjg1NTc0MTU=","avatar_url":"https://avatars.githubusercontent.com/u/8557415?v=4","gravatar_id":"","url":"https://api.github.com/users/tuukkalai","html_url":"https://github.com/tuukkalai","followers_url":"https://api.github.com/users/tuukkalai/f ...

# %%
r.json()
# Out:
# [{'id': '28826615802',
#   'type': 'PushEvent',
#   'actor': {'id': 12237117,
#    'login': 'toddsharpe',
#    'display_login': 'toddsharpe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/toddsharpe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12237117?'},
#   'repo': {'id': 535972873,
#    'name': 'toddsharpe/Embedded',
#    'url': 'https://api.github.com/repos/toddsharpe/Embedded'},
#   'payload': {'repository_id': 535972873,
#    'push_id': 13511615786,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '03f2c8014f6850d7f375c0b0b4d7680c42e612f3',
#    'before': '7fbf8375dc6ed6ec9cb8ce53a4f6bd5411a82fd7',
#    'commits': [{'sha': '7535b8d74b8d50a53656f313ffad09ef48a5952a',
#      'author': {'email': 'toddsharpe@outlook.com', 'name': 'Todd Sharpe'},
#      'message': 'External printf, Emulator ALU bug fix (OR), emulator UI',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/toddsharpe/Embedded/commits/7535b8d74b8d50a53656f313ffad09ef48a5952a'},
#     {'sha': '03f2c8014f6850d7f375c0b0b4d7680c42e612f3',
#      'author': {'email': 'toddsharpe@outlook.com', 'name': 'Todd Sharpe'},
#      'message': 'Merge pull request #23 from toddsharpe/dev/2023-04-26_remu\n\nExternal printf, Emulator ALU bug fix (OR), emulator UI',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/toddsharpe/Embedded/commits/03f2c8014f6850d7f375c0b0b4d7680c42e612f3'}]},
#   'public': True,
#   'created_at': '2023-05-03T16:31:59Z'},
#  {'id': '28826614614',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 60341450,
#    'login': 'murmurian',
#    'display_login': 'murmurian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/murmurian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60341450?'},
#   'repo': {'id': 589477904,
#    'name': 'tmc-coach/tmc-coach',
#    'url': 'https://api.github.com/repos/tmc-coach/tmc-coach'},
#   'payload': {'action': 'created',
#    'review': {'id': 1411299762,
#     'node_id': 'PRR_kwDOIyK4EM5UHrmy',
#     'user': {'login': 'murmurian',
#      'id': 60341450,
#      'node_id': 'MDQ6VXNlcjYwMzQxNDUw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/60341450?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/murmurian',
#      'html_url': 'https://github.com/murmurian',
#      'followers_url': 'https://api.github.com/users/murmurian/followers',
#      'following_url': 'https://api.github.com/users/murmurian/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/murmurian/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/murmurian/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/murmurian/subscriptions',
#      'organizations_url': 'https://api.github.com/users/murmurian/orgs',
#      'repos_url': 'https://api.github.com/users/murmurian/repos',
#      'events_url': 'https://api.github.com/users/murmurian/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/murmurian/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Nooice',
#     'commit_id': '7aefb355e328600e96b580e76d54c750b793d431',
#     'submitted_at': '2023-05-03T16:31:55Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/tmc-coach/tmc-coach/pull/247#pullrequestreview-1411299762',
#     'pull_request_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'html': {'href': 'https://github.com/tmc-coach/tmc-coach/pull/247#pullrequestreview-1411299762'},
#      'pull_request': {'href': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247',
#     'id': 1336832769,
#     'node_id': 'PR_kwDOIyK4EM5PrnMB',
#     'html_url': 'https://github.com/tmc-coach/tmc-coach/pull/247',
#     'diff_url': 'https://github.com/tmc-coach/tmc-coach/pull/247.diff',
#     'patch_url': 'https://github.com/tmc-coach/tmc-coach/pull/247.patch',
#     'issue_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues/247',
#     'number': 247,
#     'state': 'open',
#     'locked': False,
#     'title': 'Fix refactoring and cleaning',
#     'user': {'login': 'tuukkalai',
#      'id': 8557415,
#      'node_id': 'MDQ6VXNlcjg1NTc0MTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/8557415?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tuukkalai',
#      'html_url': 'https://github.com/tuukkalai',
#      'followers_url': 'https://api.github.com/users/tuukkalai/followers',
#      'following_url': 'https://api.github.com/users/tuukkalai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tuukkalai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tuukkalai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tuukkalai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tuukkalai/orgs',
#      'repos_url': 'https://api.github.com/users/tuukkalai/repos',
#      'events_url': 'https://api.github.com/users/tuukkalai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tuukkalai/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2023-05-03T14:42:08Z',
#     'updated_at': '2023-05-03T16:31:55Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'a18bd3e3d58fb4731ecc72eff7fb5fbb518133ba',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247/commits',
#     'review_comments_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247/comments',
#     'review_comment_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues/247/comments',
#     'statuses_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/statuses/7aefb355e328600e96b580e76d54c750b793d431',
#     'head': {'label': 'tmc-coach:fix-refactoring-and-cleaning',
#      'ref': 'fix-refactoring-and-cleaning',
#      'sha': '7aefb355e328600e96b580e76d54c750b793d431',
#      'user': {'login': 'tmc-coach',
#       'id': 122777204,
#       'node_id': 'O_kgDOB1FudA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/122777204?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tmc-coach',
#       'html_url': 'https://github.com/tmc-coach',
#       'followers_url': 'https://api.github.com/users/tmc-coach/followers',
#       'following_url': 'https://api.github.com/users/tmc-coach/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tmc-coach/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tmc-coach/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tmc-coach/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tmc-coach/orgs',
#       'repos_url': 'https://api.github.com/users/tmc-coach/repos',
#       'events_url': 'https://api.github.com/users/tmc-coach/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tmc-coach/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 589477904,
#       'node_id': 'R_kgDOIyK4EA',
#       'name': 'tmc-coach',
#       'full_name': 'tmc-coach/tmc-coach',
#       'private': False,
#       'owner': {'login': 'tmc-coach',
#        'id': 122777204,
#        'node_id': 'O_kgDOB1FudA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/122777204?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tmc-coach',
#        'html_url': 'https://github.com/tmc-coach',
#        'followers_url': 'https://api.github.com/users/tmc-coach/followers',
#        'following_url': 'https://api.github.com/users/tmc-coach/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tmc-coach/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tmc-coach/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tmc-coach/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tmc-coach/orgs',
#        'repos_url': 'https://api.github.com/users/tmc-coach/repos',
#        'events_url': 'https://api.github.com/users/tmc-coach/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tmc-coach/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/tmc-coach/tmc-coach',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/tmc-coach/tmc-coach',
#       'forks_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/forks',
#       'keys_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/teams',
#       'hooks_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/events',
#       'assignees_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/tags',
#       'blobs_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/languages',
#       'stargazers_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/subscription',
#       'commits_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/merges',
#       'archive_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/downloads',
#       'issues_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/deployments',
#       'created_at': '2023-01-16T08:05:32Z',
#       'updated_at': '2023-04-13T17:08:55Z',
#       'pushed_at': '2023-05-03T15:35:45Z',
#       'git_url': 'git://github.com/tmc-coach/tmc-coach.git',
#       'ssh_url': 'git@github.com:tmc-coach/tmc-coach.git',
#       'clone_url': 'https://github.com/tmc-coach/tmc-coach.git',
#       'svn_url': 'https://github.com/tmc-coach/tmc-coach',
#       'homepage': None,
#       'size': 1117,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 21,
#       'license': {'key': 'gpl-2.0',
#        'name': 'GNU General Public License v2.0',
#        'spdx_id': 'GPL-2.0',
#        'url': 'https://api.github.com/licenses/gpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTg='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 21,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'tmc-coach:main',
#      'ref': 'main',
#      'sha': 'fdfebee27a41aea141ae6df26033853acaeae4b1',
#      'user': {'login': 'tmc-coach',
#       'id': 122777204,
#       'node_id': 'O_kgDOB1FudA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/122777204?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tmc-coach',
#       'html_url': 'https://github.com/tmc-coach',
#       'followers_url': 'https://api.github.com/users/tmc-coach/followers',
#       'following_url': 'https://api.github.com/users/tmc-coach/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tmc-coach/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tmc-coach/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tmc-coach/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tmc-coach/orgs',
#       'repos_url': 'https://api.github.com/users/tmc-coach/repos',
#       'events_url': 'https://api.github.com/users/tmc-coach/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tmc-coach/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 589477904,
#       'node_id': 'R_kgDOIyK4EA',
#       'name': 'tmc-coach',
#       'full_name': 'tmc-coach/tmc-coach',
#       'private': False,
#       'owner': {'login': 'tmc-coach',
#        'id': 122777204,
#        'node_id': 'O_kgDOB1FudA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/122777204?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tmc-coach',
#        'html_url': 'https://github.com/tmc-coach',
#        'followers_url': 'https://api.github.com/users/tmc-coach/followers',
#        'following_url': 'https://api.github.com/users/tmc-coach/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tmc-coach/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tmc-coach/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tmc-coach/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tmc-coach/orgs',
#        'repos_url': 'https://api.github.com/users/tmc-coach/repos',
#        'events_url': 'https://api.github.com/users/tmc-coach/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tmc-coach/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/tmc-coach/tmc-coach',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/tmc-coach/tmc-coach',
#       'forks_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/forks',
#       'keys_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/teams',
#       'hooks_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/events',
#       'assignees_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/tags',
#       'blobs_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/languages',
#       'stargazers_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/subscription',
#       'commits_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/merges',
#       'archive_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/downloads',
#       'issues_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tmc-coach/tmc-coach/deployments',
#       'created_at': '2023-01-16T08:05:32Z',
#       'updated_at': '2023-04-13T17:08:55Z',
#       'pushed_at': '2023-05-03T15:35:45Z',
#       'git_url': 'git://github.com/tmc-coach/tmc-coach.git',
#       'ssh_url': 'git@github.com:tmc-coach/tmc-coach.git',
#       'clone_url': 'https://github.com/tmc-coach/tmc-coach.git',
#       'svn_url': 'https://github.com/tmc-coach/tmc-coach',
#       'homepage': None,
#       'size': 1117,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 21,
#       'license': {'key': 'gpl-2.0',
#        'name': 'GNU General Public License v2.0',
#        'spdx_id': 'GPL-2.0',
#        'url': 'https://api.github.com/licenses/gpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTg='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 21,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247'},
#      'html': {'href': 'https://github.com/tmc-coach/tmc-coach/pull/247'},
#      'issue': {'href': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues/247'},
#      'comments': {'href': 'https://api.github.com/repos/tmc-coach/tmc-coach/issues/247/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tmc-coach/tmc-coach/pulls/247/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tmc-coach/tmc-coach/statuses/7aefb355e328600e96b580e76d54c750b793d431'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-05-03T16:31:56Z',
#   'org': {'id': 122777204,
#    'login': 'tmc-coach',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tmc-coach',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/122777204?'}},
#  {'id': '28826615055',
#   'type': 'CreateEvent',
#   'actor': {'id': 58984962,
#    'login': 'harshitdubey8',
#    'display_login': 'harshitdubey8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harshitdubey8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58984962?'},
#   'repo': {'id': 635874535,
#    'name': 'harshitdubey8/orufyAssignment',
#    'url': 'https://api.github.com/repos/harshitdubey8/orufyAssignment'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-05-03T16:31:57Z'},
#  {'id': '28826615476',
#   'type': 'CreateEvent',
#   'actor': {'id': 112755279,
#    'login': 'alexanderqmv',
#    'display_login': 'alexanderqmv',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexanderqmv',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112755279?'},
#   'repo': {'id': 635874541,
#    'name': 'alexanderqmv/RustFM',
#    'url': 'https://api.github.com/repos/alexanderqmv/RustFM'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'RustFM -  Simple wrapper of a File Manager System that allows you to easily manipulate with files.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-05-03T16:31:58Z'},
#  {'id': '28826615758',
#   'type': 'PushEvent',
#   'actor': {'id': 30682875,
#    'login': 'jo-tm',
#    'display_login': 'jo-tm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jo-tm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30682875?'},
#   'repo': {'id': 593696305,
#    'name': 'Trust-Machines/core-eng',
#    'url': 'https://api.github.com/repos/Trust-Machines/core-eng'},
#   'payload': {'repository_id': 593696305,
#    'push_id': 13511615749,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/clarity/sbtc-mini-token-unit-tests',
#    'head': 'dfe5e1d7fbda1137c18cc1d999f69a4d74f08def',
#    'before': '88fe1416d7237814d289a93d8723845d22d83c63',
#    'commits': [{'sha': 'dfe5e1d7fbda1137c18cc1d999f69a4d74f08def',
#      'author': {'email': '30682875+jo-tm@users.noreply.github.com',
#       'name': 'José'},
#      'message': 'Update test.sh',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Trust-Machines/core-eng/commits/dfe5e1d7fbda1137c18cc1d999f69a4d74f08def'}]},
#   'public': True,
#   'created_at': '2023-05-03T16:31:59Z',
#   'org': {'id': 95502587,
#    'login': 'Trust-Machines',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Trust-Machines',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95502587?'}},
#  {'id': '28826615775',
#   'type': 'PushEvent',
#   'actor': {'id': 44686783,
#    'login': 'Morovane',
#    'display_login': 'Morovane',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Morovane',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44686783?'},
#   'repo': {'id': 614948788,
#    'name': 'Morovane/alx-low_level_programming',
#    'url': 'https://api.github.com/repos/Morovane/alx-low_level_programming'},
#   'payload': {'repository_id': 614948788,
#    'push_id': 13511615775,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bc7839f43f802cc4fa65865bc19cbf35bd18ef44',
#    'before': '14b3c0d9e29e9a3d60879d77fb45dcce581c3894',
#    'commits': [{'sha': 'bc7839f43f802cc4fa65865bc19cbf35bd18ef44',
#      'author': {'email': 'elfilalimarouane.1997@gmail.com',
#       'name': 'Morovane'},
#      'message': 'Write a function that returns the sum of all the data (n) of a listint_t linked list.\n\nPrototype: int sum_listint(listint_t *head);\nif the list is empty, return 0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Morovane/alx-low_level_programming/commits/bc7839f43f802cc4fa65865bc19cbf35bd18ef44'}]},
#   'public': True,
#   'created_at': '2023-05-03T16:31:59Z'},
#  {'id': '28826615406',
#   'type': 'PushEvent',
#   'actor': {'id': 123278350,
#    'login': 'bmarani',
#    'display_login': 'bmarani',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bmarani',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123278350?'},
#   'repo': {'id': 621597484,
#    'name': 'NJIT-WIS/project-2-dream-team',
#    'url': 'https://api.github.com/repos/NJIT-WIS/project-2-dream-team'},
#   'payload': {'repository_id': 621597484,
#    'push_id': 13511615589,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/82-volunteerpagefix',
#    'head': '28008f93667699cd75418ad8ae1b7063ea516b04',
#    'before': '60adce624290f7c52881371dc051579d941734ac',
#    'commits': [{'sha': '28008f93667699cd75418ad8ae1b7063ea516b04',
#      'author': {'email': 'bm383@njit.edu', 'name': 'bmarani'},
#      'message': 'fixed volunteer page template',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NJIT-WIS/project-2-dream-team/commits/28008f93667699cd75418ad8ae1b7063ea516b04'}]},
#   'public': True,
#   'created_at': '2023-05-03T16:31:58Z',
#   'org': {'id': 10761034,
#    'login': 'NJIT-WIS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NJIT-WIS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10761034?'}},
#  {'id': '28826615759',
#   'type': 'PushEvent',
#   'actor': {'id': 81702840,
#    'login': 'Knya3ev',
#    'display_login': 'Knya3ev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Knya3ev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81702840?'},
#   'repo': {'id': 634508810,
#    'name': 'Knya3ev/cloud-config',
#    'url': 'https://api.github.com/repos/Knya3ev/cloud-config'},
#   'payload': {'repository_id': 634508810,
#    'push_id': 13511615753,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aafc2cb19ce04e18d79b71c36532a173e363257c',
#    'before': '63b4155dda96ae72bd0c1fec40cfc37887c9d006',
#    'commits': [{'sha': 'aafc2cb19ce04e18d79b71c36532a173e363257c',
#      'author': {'email': 'knyazev193@yandex.ru', 'name': 'Mikhail Knyazev'},
#      'message': 'first commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Knya3ev/cloud-config/commits/aafc2cb19ce04e18d79b71c36532a173e363257c'}]},
#   'public': True,
#   'created_at': '2023-05-03T16:31:59Z'},
#  {'id': '28826615743',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 600744325,
#    'name': 'will1211/YouTube_to_m3u',
#    'url': 'https://api.github.com/repos/will1211/YouTube_to_m3u'},
#   'payload': {'repository_id': 600744325,
#    'push_id': 13511615717,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9cf8b87b7fa47b6efd57b7892e660d8ca293c631',
#    'before': '212d11730edb6fba4004c42009aa349e34a7de66',
#    'commits': [{'sha': '9cf8b87b7fa47b6efd57b7892e660d8ca293c631',
#      'author': {'email': 'nbknri@gmail.com', 'name': 'nbknri'},
#      'message': 'link is updated',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/will1211/YouTube_to_m3u/commits/9cf8b87b7fa47b6efd57b7892e660d8ca293c631'}]},
#   'public': True,
#   'created_at': '2023-05-03T16:31:59Z'},
#  {'id': '28826614677',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 579960519,
#    'name': 'leamas/zulip-archive',
#    'url': 'https://api.github.com/repos/leamas/zulip-archive'},
#   'payload': {'repository_id': 579960519,
#    'push_id': 13511615161,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '32d8209fee0b58d6bce893dfffb7cf5a97cb3178',
#    'before': '86aa72fa7b4e65f95907355da722322c228da566',
#    'commits': [{'sha': '32d8209fee0b58d6bce893dfffb7cf5a97cb3178',
#      'author': {'email': 'zulip-archive-bot@users.noreply.github.com',
#       'name': 'Archive Bot'},
#      'message': 'Update archive.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/leamas/zulip-archive/commits/32d8209fee0b58d6bce893dfffb7cf5a97cb3178'}]},
#   'public': True,
#   'created_at': '2023-05-03T16:31:56Z'},
#  {'id': '28826614681',
#   'type': 'PushEvent',
#   'actor': {'id': 117822622,
#    'login': 'tedygreat',
#    'display_login': 'tedygreat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tedygreat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117822622?'},
#   'repo': {'id': 572521708,
#    'name': 'tedygreat/alx-system_engineering-devops',
#    'url': 'https://api.github.com/repos/tedygreat/alx-system_engineering-devops'},
#   'payload': {'repository_id': 572521708,
#    'push_id': 13511615240,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3906d94f5bd12dfcc8d4df2191f4c2d63ae533a8',
#    'before': 'c83b2c9d9774323f4aa862d292dffddff139bce4',
#    'commits': [{'sha': '3906d94f5bd12dfcc8d4df2191f4c2d63ae533a8',
#      'author': {'email': 'tedygreat@gmail.com', 'name': 'tedygreat'},
#      'message': 'task 3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tedygreat/alx-system_engineering-devops/commits/3906d94f5bd12dfcc8d4df2191f4c2d63ae533a8'}]},
#   'public': True,
#   'created_at': '2023-05-03T16:31:56Z'},
#  {'id': '28826615380',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 157182,
#    'login': 'dajac',
#    'display_login': 'dajac',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dajac',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157182?'},
#   'repo': {'id': 2211243,
#    'name': 'apache/kafka',
#    'url': 'https://api.github.com/repos/apache/kafka'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/apache/kafka/pulls/comments/1183933777',
#     'pull_request_review_id': 1411299808,
#     'id': 1183933777,
#     'node_id': 'PRRC_kwDOACG9q85GkWVR',
#     'diff_hunk': '@@ -0,0 +1,415 @@\n+/*\n+ * Licensed to the Apache Software Foundation (ASF) under one or more\n+ * contributor license agreements. See the NOTICE file distributed with\n+ * this work for additional information regarding copyright ownership.\n+ * The ASF licenses this file to You under the Apache License, Version 2.0\n+ * (the "License"); you may not use this file except in compliance with\n+ * the License. You may obtain a copy of the License at\n+ *\n+ *    http://www.apache.org/licenses/LICENSE-2.0\n+ *\n+ * Unless required by applicable law or agreed to in writing, software\n+ * distributed under the License is distributed on an "AS IS" BASIS,\n+ * WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.\n+ * See the License for the specific language governing permissions and\n+ * limitations under the License.\n+ */\n+package org.apache.kafka.coordinator.group.consumer;\n+\n+import org.apache.kafka.common.Uuid;\n+import org.apache.kafka.common.message.ConsumerGroupHeartbeatRequestData;\n+\n+import java.util.Collections;\n+import java.util.HashMap;\n+import java.util.HashSet;\n+import java.util.Iterator;\n+import java.util.List;\n+import java.util.Map;\n+import java.util.Objects;\n+import java.util.Set;\n+import java.util.function.BiFunction;\n+\n+/**\n+ * The CurrentAssignmentBuilder class encapsulates the reconciliation engine of the\n+ * consumer group protocol. Given the current state of a member and a desired or target\n+ * assignment state, the state machine takes the necessary steps to converge them.\n+ *\n+ * The member state has the following properties:\n+ * - Current Epoch  - The current epoch of the member.\n+ * - Next Epoch     - The desired epoch of the member. It corresponds to the epoch of\n+ *                    the target/desired assignment. The member transitions to this epoch\n+ *                    when it has revoked the partitions that it does not own or if it\n+ *                    does not have to revoke any.\n+ * - Previous Epoch - The previous epoch of the member when the state was updated.',
#     'path': 'group-coordinator/src/main/java/org/apache/kafka/coordinator/group/consumer/CurrentAssignmentBuilder.java',
#     'commit_id': 'cd2a8353a15dd27f72aa3c6acc76d002450db63d',
#     'original_commit_id': 'adb8672ba286a6dfc17de9b0bb848de412fe6f33',
#     'user': {'login': 'dajac',
#      'id': 157182,
#      'node_id': 'MDQ6VXNlcjE1NzE4Mg==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/157182?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dajac',
#      'html_url': 'https://github.com/dajac',
#      'followers_url': 'https://api.github.com/users/dajac/followers',
#      'following_url': 'https://api.github.com/users/dajac/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dajac/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dajac/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dajac/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dajac/orgs',
#      'repos_url': 'https://api.github.com/users/dajac/repos',
#      'events_url': 'https://api.github.com/users/dajac/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dajac/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Will do.',
#     'created_at': '2023-05-03T16:31:57Z',
#     'updated_at': '2023-05-03T16:31:57Z',
#     'html_url': 'https://github.com/apache/kafka/pull/13638#discussion_r1183933777',
#     'pull_request_url': 'https://api.github.com/repos/apache/kafka/pulls/13638',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/apache/kafka/pulls/comments/1183933777'},
#      'html': {'href': 'https://github.com/apache/kafka/pull/13638#discussion_r1183933777'},
#      'pull_request': {'href': 'https://api.github.com/repos/apache/kafka/pulls/13638'}},
#     'reactions': {'url': 'https://api.github.com/repos/apache/kafka/pulls/comments/1183933777/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': None,
#     'original_line': 43,
#     'side': 'RIGHT',
#     'in_reply_to_id': 1183155377,
#     'original_position': 43,
#     'position': None,
#     'subject_type': 'line'},
#    'pull_request': {'url': 'https://api.github.com/repos/apache/kafka/pulls/13638',
#     'id': 1327060013,
#     'node_id': 'PR_kwDOACG9q85PGVQt',
#     'html_url': 'https://github.com/apache/kafka/pull/13638',
#     'diff_url': 'https://github.com/apache/kafka/pull/13638.diff',
#     'patch_url': 'https://github.com/apache/kafka/pull/13638.patch',
#     'issue_url': 'https://api.github.com/repos/apache/kafka/issues/13638',
#     'number': 13638,
#     'state': 'open',
#     'locked': False,
#     'title': 'KAFKA-14462; [11/N] Add CurrentAssignmentBuilder',
#     'user': {'login': 'dajac',
#      'id': 157182,
#      'node_id': 'MDQ6VXNlcjE1NzE4Mg==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/157182?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dajac',
#      'html_url': 'https://github.com/dajac',
#      'followers_url': 'https://api.github.com/users/dajac/followers',
#      'following_url': 'https://api.github.com/users/dajac/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dajac/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dajac/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dajac/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dajac/orgs',
#      'repos_url': 'https://api.github.com/users/dajac/repos',
#      'events_url': 'https://api.github.com/users/dajac/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dajac/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This patch adds CurrentAssignmentBuilder.\r\n\r\n### Committer Checklist (excluded from commit message)\r\n- [ ] Verify design and implementation \r\n- [ ] Verify test coverage and CI build status\r\n- [ ] Verify documentation (including upgrade notes)\r\n',
#     'created_at': '2023-04-25T12:32:31Z',
#     'updated_at': '2023-05-03T16:31:58Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '808f4603220ca45f0b4b4434a574265d9a893c22',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 4771354362,
#       'node_id': 'LA_kwDOACG9q88AAAABHGUW-g',
#       'url': 'https://api.github.com/repos/apache/kafka/labels/KIP-848',
#       'name': 'KIP-848',
#       'color': '0E87F1',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/apache/kafka/pulls/13638/commits',
#     'review_comments_url': 'https://api.github.com/repos/apache/kafka/pulls/13638/comments',
#     'review_comment_url': 'https://api.github.com/repos/apache/kafka/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/apache/kafka/issues/13638/comments',
#     'statuses_url': 'https://api.github.com/repos/apache/kafka/statuses/cd2a8353a15dd27f72aa3c6acc76d002450db63d',
#     'head': {'label': 'dajac:KAFKA-14462-11',
#      'ref': 'KAFKA-14462-11',
#      'sha': 'cd2a8353a15dd27f72aa3c6acc76d002450db63d',
#      'user': {'login': 'dajac',
#       'id': 157182,
#       'node_id': 'MDQ6VXNlcjE1NzE4Mg==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/157182?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dajac',
#       'html_url': 'https://github.com/dajac',
#       'followers_url': 'https://api.github.com/users/dajac/followers',
#       'following_url': 'https://api.github.com/users/dajac/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dajac/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dajac/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dajac/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dajac/orgs',
#       'repos_url': 'https://api.github.com/users/dajac/repos',
#       'events_url': 'https://api.github.com/users/dajac/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dajac/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 40044750,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0MDA0NDc1MA==',
#       'name': 'kafka',
#       'full_name': 'dajac/kafka',
#       'private': False,
#       'owner': {'login': 'dajac',
#        'id': 157182,
#        'node_id': 'MDQ6VXNlcjE1NzE4Mg==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/157182?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dajac',
#        'html_url': 'https://github.com/dajac',
#        'followers_url': 'https://api.github.com/users/dajac/followers',
#        'following_url': 'https://api.github.com/users/dajac/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dajac/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dajac/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dajac/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dajac/orgs',
#        'repos_url': 'https://api.github.com/users/dajac/repos',
#        'events_url': 'https://api.github.com/users/dajac/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dajac/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/dajac/kafka',
#       'description': 'Mirror of Apache Kafka',
#       'fork': True,
#       'url': 'https://api.github.com/repos/dajac/kafka',
#       'forks_url': 'https://api.github.com/repos/dajac/kafka/forks',
#       'keys_url': 'https://api.github.com/repos/dajac/kafka/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dajac/kafka/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dajac/kafka/teams',
#       'hooks_url': 'https://api.github.com/repos/dajac/kafka/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dajac/kafka/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dajac/kafka/events',
#       'assignees_url': 'https://api.github.com/repos/dajac/kafka/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dajac/kafka/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dajac/kafka/tags',
#       'blobs_url': 'https://api.github.com/repos/dajac/kafka/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dajac/kafka/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dajac/kafka/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dajac/kafka/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dajac/kafka/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dajac/kafka/languages',
#       'stargazers_url': 'https://api.github.com/repos/dajac/kafka/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dajac/kafka/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dajac/kafka/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dajac/kafka/subscription',
#       'commits_url': 'https://api.github.com/repos/dajac/kafka/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dajac/kafka/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dajac/kafka/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dajac/kafka/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dajac/kafka/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dajac/kafka/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dajac/kafka/merges',
#       'archive_url': 'https://api.github.com/repos/dajac/kafka/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dajac/kafka/downloads',
#       'issues_url': 'https://api.github.com/repos/dajac/kafka/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dajac/kafka/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dajac/kafka/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dajac/kafka/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dajac/kafka/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dajac/kafka/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dajac/kafka/deployments',
#       'created_at': '2015-08-01T11:38:46Z',
#       'updated_at': '2023-01-31T16:38:50Z',
#       'pushed_at': '2023-05-03T13:05:41Z',
#       'git_url': 'git://github.com/dajac/kafka.git',
#       'ssh_url': 'git@github.com:dajac/kafka.git',
#       'clone_url': 'https://github.com/dajac/kafka.git',
#       'svn_url': 'https://github.com/dajac/kafka',
#       'homepage': None,
#       'size': 142648,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Scala',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'trunk'}},
#     'base': {'label': 'apache:trunk',
#      'ref': 'trunk',
#      'sha': '16fc8e1cfff6f0ac29209704a079b0ddcbd0625e',
#      'user': {'login': 'apache',
#       'id': 47359,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3MzU5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/47359?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/apache',
#       'html_url': 'https://github.com/apache',
#       'followers_url': 'https://api.github.com/users/apache/followers',
#       'following_url': 'https://api.github.com/users/apache/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/apache/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/apache/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/apache/subscriptions',
#       'organizations_url': 'https://api.github.com/users/apache/orgs',
#       'repos_url': 'https://api.github.com/users/apache/repos',
#       'events_url': 'https://api.github.com/users/apache/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/apache/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 2211243,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjExMjQz',
#       'name': 'kafka',
#       'full_name': 'apache/kafka',
#       'private': False,
#       'owner': {'login': 'apache',
#        'id': 47359,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3MzU5',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/47359?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/apache',
#        'html_url': 'https://github.com/apache',
#        'followers_url': 'https://api.github.com/users/apache/followers',
#        'following_url': 'https://api.github.com/users/apache/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/apache/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/apache/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/apache/subscriptions',
#        'organizations_url': 'https://api.github.com/users/apache/orgs',
#        'repos_url': 'https://api.github.com/users/apache/repos',
#        'events_url': 'https://api.github.com/users/apache/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/apache/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/apache/kafka',
#       'description': 'Mirror of Apache Kafka',
#       'fork': False,
# ...
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'ohcmadah:main',
#      'ref': 'main',
#      'sha': '0c4af442b3d2b4f18745048477b2d3cdc31747ca',
#      'user': {'login': 'ohcmadah',
#       'id': 52340070,
#       'node_id': 'MDQ6VXNlcjUyMzQwMDcw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/52340070?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ohcmadah',
#       'html_url': 'https://github.com/ohcmadah',
#       'followers_url': 'https://api.github.com/users/ohcmadah/followers',
#       'following_url': 'https://api.github.com/users/ohcmadah/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ohcmadah/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ohcmadah/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ohcmadah/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ohcmadah/orgs',
#       'repos_url': 'https://api.github.com/users/ohcmadah/repos',
#       'events_url': 'https://api.github.com/users/ohcmadah/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ohcmadah/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 635354610,
#       'node_id': 'R_kgDOJd698g',
#       'name': 'pre-onboarding-10th-2-9',
#       'full_name': 'ohcmadah/pre-onboarding-10th-2-9',
#       'private': False,
#       'owner': {'login': 'ohcmadah',
#        'id': 52340070,
#        'node_id': 'MDQ6VXNlcjUyMzQwMDcw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/52340070?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ohcmadah',
#        'html_url': 'https://github.com/ohcmadah',
#        'followers_url': 'https://api.github.com/users/ohcmadah/followers',
#        'following_url': 'https://api.github.com/users/ohcmadah/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ohcmadah/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ohcmadah/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ohcmadah/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ohcmadah/orgs',
#        'repos_url': 'https://api.github.com/users/ohcmadah/repos',
#        'events_url': 'https://api.github.com/users/ohcmadah/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ohcmadah/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ohcmadah/pre-onboarding-10th-2-9',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9',
#       'forks_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/forks',
#       'keys_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/teams',
#       'hooks_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/events',
#       'assignees_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/tags',
#       'blobs_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/languages',
#       'stargazers_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/subscription',
#       'commits_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/merges',
#       'archive_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/downloads',
#       'issues_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/deployments',
#       'created_at': '2023-05-02T14:12:01Z',
#       'updated_at': '2023-05-02T14:32:17Z',
#       'pushed_at': '2023-05-03T16:31:57Z',
#       'git_url': 'git://github.com/ohcmadah/pre-onboarding-10th-2-9.git',
#       'ssh_url': 'git@github.com:ohcmadah/pre-onboarding-10th-2-9.git',
#       'clone_url': 'https://github.com/ohcmadah/pre-onboarding-10th-2-9.git',
#       'svn_url': 'https://github.com/ohcmadah/pre-onboarding-10th-2-9',
#       'homepage': None,
#       'size': 418,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/pulls/10'},
#      'html': {'href': 'https://github.com/ohcmadah/pre-onboarding-10th-2-9/pull/10'},
#      'issue': {'href': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/issues/10'},
#      'comments': {'href': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/issues/10/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/pulls/10/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/pulls/10/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ohcmadah/pre-onboarding-10th-2-9/statuses/51ef7dd34d5415f7ff07b5c17645eb7b4c626fcf'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'ohcmadah',
#      'id': 52340070,
#      'node_id': 'MDQ6VXNlcjUyMzQwMDcw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/52340070?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ohcmadah',
#      'html_url': 'https://github.com/ohcmadah',
#      'followers_url': 'https://api.github.com/users/ohcmadah/followers',
#      'following_url': 'https://api.github.com/users/ohcmadah/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ohcmadah/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ohcmadah/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ohcmadah/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ohcmadah/orgs',
#      'repos_url': 'https://api.github.com/users/ohcmadah/repos',
#      'events_url': 'https://api.github.com/users/ohcmadah/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ohcmadah/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 238,
#     'deletions': 98,
#     'changed_files': 18}},
#   'public': True,
#   'created_at': '2023-05-03T16:31:58Z'},
#  {'id': '28826614983',
#   'type': 'ForkEvent',
#   'actor': {'id': 102864903,
#    'login': 'Ugbahaski',
#    'display_login': 'Ugbahaski',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ugbahaski',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102864903?'},
#   'repo': {'id': 162811476,
#    'name': 'Ro9ueAdmin/EvilApp',
#    'url': 'https://api.github.com/repos/Ro9ueAdmin/EvilApp'},
#   'payload': {'forkee': {'id': 635874534,
#     'node_id': 'R_kgDOJeas5g',
#     'name': 'EvilApp',
#     'full_name': 'Ugbahaski/EvilApp',
#     'private': False,
#     'owner': {'login': 'Ugbahaski',
#      'id': 102864903,
#      'node_id': 'U_kgDOBiGYBw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/102864903?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Ugbahaski',
#      'html_url': 'https://github.com/Ugbahaski',
#      'followers_url': 'https://api.github.com/users/Ugbahaski/followers',
#      'following_url': 'https://api.github.com/users/Ugbahaski/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Ugbahaski/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Ugbahaski/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Ugbahaski/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Ugbahaski/orgs',
#      'repos_url': 'https://api.github.com/users/Ugbahaski/repos',
#      'events_url': 'https://api.github.com/users/Ugbahaski/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Ugbahaski/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/Ugbahaski/EvilApp',
#     'description': 'Script to generate Android App that can hijack autenticated sessions in cookies',
#     'fork': True,
#     'url': 'https://api.github.com/repos/Ugbahaski/EvilApp',
#     'forks_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/forks',
#     'keys_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/teams',
#     'hooks_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/events',
#     'assignees_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/tags',
#     'blobs_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/languages',
#     'stargazers_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/stargazers',
#     'contributors_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/contributors',
#     'subscribers_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/subscribers',
#     'subscription_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/subscription',
#     'commits_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/merges',
#     'archive_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/downloads',
#     'issues_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/Ugbahaski/EvilApp/deployments',
#     'created_at': '2023-05-03T16:31:56Z',
#     'updated_at': '2023-05-03T16:31:56Z',
#     'pushed_at': '2018-12-21T17:25:09Z',
#     'git_url': 'git://github.com/Ugbahaski/EvilApp.git',
#     'ssh_url': 'git@github.com:Ugbahaski/EvilApp.git',
#     'clone_url': 'https://github.com/Ugbahaski/EvilApp.git',
#     'svn_url': 'https://github.com/Ugbahaski/EvilApp',
#     'homepage': None,
#     'size': 1110,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2023-05-03T16:31:57Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %% [markdown]
# ### Paginando os repositórios

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %% [markdown]
# ### Linguagens dos repositórios

# %% [markdown]
# ### Criando um DataFrame

# %% [markdown]
# Salvando o DataFrame

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %% [markdown]
# ### Formato do arquivo

# %% [markdown]
# ### Upload de arquivo com PUT
